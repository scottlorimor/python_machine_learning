# %% [markdown]
# # kNN for Classification

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os

from sklearn.neighbors import KNeighborsClassifier
from sklearn.cross_validation import train_test_split

# %matplotlib inline

# %%
# load in iris dataset
iris_dataset = "../datasets/iris.data.txt"
iris = pd.read_csv(iris_dataset)
iris.columns = ['sepal_length_cm', 'sepal_width_cm', 'petal_length_cm', 'petal_width_cm', 'species']

# os.path.isfile(iris_dataset)

# %%
# using .head() to get a feel for the values in the dataset

iris.head()
# Out:
#    sepal_length_cm  sepal_width_cm  petal_length_cm  petal_width_cm  \
# 0              4.9             3.0              1.4             0.2
# 1              4.7             3.2              1.3             0.2
# 2              4.6             3.1              1.5             0.2
# 3              5.0             3.6              1.4             0.2
# 4              5.4             3.9              1.7             0.4
#
#        species
# 0  Iris-setosa
# 1  Iris-setosa
# 2  Iris-setosa
# 3  Iris-setosa
# 4  Iris-setosa

# %%
# get some descriptive stats about the dataset
iris.describe()
# Out:
#        sepal_length_cm  sepal_width_cm  petal_length_cm  petal_width_cm
# count       149.000000      149.000000       149.000000      149.000000
# mean          5.848322        3.051007         3.774497        1.205369
# std           0.828594        0.433499         1.759651        0.761292
# min           4.300000        2.000000         1.000000        0.100000
# 25%           5.100000        2.800000         1.600000        0.300000
# 50%           5.800000        3.000000         4.400000        1.300000
# 75%           6.400000        3.300000         5.100000        1.800000
# max           7.900000        4.400000         6.900000        2.500000

# %%
sns.set(context='notebook')
colors = 'cgb'
sns.pairplot(iris,hue='species',size=2.5)

# %% [markdown]
# I should spend more time with EDA with this particular dataset, but will just get into modeling it for this notebook.

# %%
# split dataset into test/train sets

X_train, X_test, y_train, y_test = train_test_split(iris[['sepal_length_cm', 'sepal_width_cm', 'petal_length_cm',
                                                        'petal_width_cm']],iris['species'], test_size=0.3, 
                                                   random_state=42)
X_train.shape, y_train.shape
# print len(X_test)
# Out:
# ((104, 4), (104,))

# %%
# training model on entire dataset for testing
features = ['sepal_length_cm', 'sepal_width_cm', 'petal_length_cm','petal_width_cm']
target = ['species']
X = iris.iloc[:,:4]
y = iris['species']

model = KNeighborsClassifier(n_neighbors=11)
model.fit(X, y)
predictions = model.predict(X) #returns predictions array
accuracy = model.score(X,y) 
print "predicted model accuracy: {0}".format(str(accuracy))
# Out:
# predicted model accuracy: 0.973154362416
